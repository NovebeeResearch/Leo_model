# %%
#@title Setup
# !git clone https://github.com/tamarott/SinGAN.git
# %cd /content/SinGAN
# !pip install -q -r requirements.txt
# !pip install torch==1.4.0 
# !pip install torchvision==0.5.0
# Out:
# Cloning into 'SinGAN'...
# remote: Enumerating objects: 811, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 811 (delta 1), reused 2 (delta 1), pack-reused 806
# Receiving objects: 100% (811/811), 94.89 MiB | 14.32 MiB/s, done.
# Resolving deltas: 100% (315/315), done.

# %%
#you should specify the image you want to train in the model, the image need to locate within ./SinGAN/Input/Images/ folder
# !python main_train.py --input_name 'Land.jpg'
# Out:
# Random Seed:  9330
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (body): Sequential(
#     (block1): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block2): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block3): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
# ...

# %%
#you should specify the image you want to generate random samples and before you generate new random samples images, 
#you need to train it first, the image need to locate within ./SinGAN/Input/Images/ folder
# !python random_samples.py --input_name 'Land.jpg' --mode random_samples --gen_start_scale 0
#the output images would be saved in ./SinGAN/Output/RandomSamples/your_images_name folder
# Out:
# Random Seed:  3735
# random samples for image Land.jpg, start scale=0, already exist

# %%
#zip the output, then we can easily download it from colab
# !zip -r Land.zip Output/RandomSamples/Land
# Out:
#   adding: Output/RandomSamples/Land/ (stored 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/ (stored 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/39.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/11.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/1.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/37.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/24.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/42.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/7.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/15.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/34.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/32.png (deflated 0%)
#   adding: Output/RandomSamples/Land/gen_start_scale=0/0.png (deflated 0%)
# ...
